# %%
#EDA OF FOOD DELIVERY COMPANY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/Dell/Downloads/Swiggy/EDA-Food delivery company.csv")

# %%
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
df.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
df.shape
# Out:
# (8680, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
#Check for null values

df.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
#no missing values in the dataset

# %%
#Now check for duplicate rows
# Check for duplicate rows
d_row = df.duplicated().sum()
d_row
# Out:
# 0

# %%
#data types
df.dtypes
# Out:
# ID                 int64
# Area              object
# City              object
# Restaurant        object
# Price            float64
# Avg ratings      float64
# Total ratings      int64
# Food type         object
# Address           object
# Delivery time      int64
# dtype: object

# %%
#columns
df.columns
# Out:
# Index(['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
#        'Total ratings', 'Food type', 'Address', 'Delivery time'],
#       dtype='object')

# %%
#Descriptive Stats
Stats=df[['Price', 'Avg ratings', 'Delivery time']].describe()
Stats
# Out:
#              Price  Avg ratings  Delivery time
# count  8680.000000  8680.000000    8680.000000
# mean    348.444470     3.655104      53.967051
# std     230.940074     0.647629      14.292335
# min       0.000000     2.000000      20.000000
# 25%     200.000000     2.900000      44.000000
# 50%     300.000000     3.900000      53.000000
# 75%     400.000000     4.200000      64.000000
# max    2500.000000     5.000000     109.000000

# %%
df=df[df['Price'] > 0]     #removing data with price 0
df['Price'].describe()
# Out:
# count    8675.000000
# mean      348.645303
# std       230.855006
# min         1.000000
# 25%       200.000000
# 50%       300.000000
# 75%       400.000000
# max      2500.000000
# Name: Price, dtype: float64

# %%
#city and area columns are enough and address can be dropped
df=df.drop(columns=['Address'])
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
#dropping id column
df=df.drop('ID',axis=1)
df
# Out:
#                         Area       City                Restaurant  Price  \
# 0                Koramangala  Bangalore               Tandoor Hut  300.0
# 1                Koramangala  Bangalore             Tunday Kababi  300.0
# 2                  Jogupalya  Bangalore                   Kim Lee  650.0
# 3                Indiranagar  Bangalore         New Punjabi Hotel  250.0
# 4                Indiranagar  Bangalore                       Nh8  350.0
# ...                      ...        ...                       ...    ...
# 8675  Panjarapole Cross Road  Ahmedabad                Malt Pizza  500.0
# 8676                  Rohini      Delhi  Jay Mata Ji Home Kitchen  200.0
# 8677                  Rohini      Delhi      Chinese Kitchen King  150.0
# 8678                  Rohini      Delhi    Shree Ram Paratha Wala  150.0
# 8679             Navrangpura  Ahmedabad              Sassy Street  250.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# ...

# %%
df['Area'].unique()
# Out:
# array(['Koramangala', 'Jogupalya', 'Indiranagar', 'Domlur', 'Cooke Town',
#        'Pulikeshi Nagar', 'Sivanchetti Gardens', 'Kodihalli', 'Jayanagar',
#        'Film Nagar', 'Banashankari', 'Masab Tank', 'Banjara Hills',
#        'Andheri East', 'Powai', 'Punjagutta', 'Aundh', 'Baner',
#        'Powai Area', 'Ramgopalpet', 'Kalasiguda', 'Adarsh Nagar',
#        'Himayatnagar', 'Ashok Nagar', 'Commercial Street',
#        'Richmond Town', 'Vasanth Nagar', 'Bhowanipore', 'Ballygunge',
#        'Gariahat', 'Kalighat', 'Sion', 'Mumbai', 'Rajajinagar', 'Golpark',
#        'Shivajinagar', 'Koregaon Park', 'Deccan Gymkhana', 'Karkhana',
#        'Kothrud', 'Erandwane', 'Koti', 'Dilsukhnagar', 'Nagole',
#        'Chandrapuri Colony', 'Kothapet', 'Narayanguda', 'Fc Road',
#        'Park Street Area', 'Beniapukur', 'Bidhannagar', 'New Nallakunta',
#        'Adikmet', 'Amberpet', 'Karve Nagar', 'Agarkar Nagar', 'Mundhwa',
# ...

# %%
df['City'].unique()
# Out:
# array(['Bangalore', 'Hyderabad', 'Mumbai', 'Pune', 'Kolkata', 'Delhi',
#        'Chennai', 'Ahmedabad', 'Surat'], dtype=object)

# %%
df['Food type'].value_counts()
# Out:
# Food type
# Indian                                                      389
# Chinese                                                     277
# North Indian                                                246
# Fast Food                                                   240
# South Indian                                                227
#                                                            ...
# Healthy Food  Juices  Continental                             1
# Bengali  Indian  Combo                                        1
# South Indian,Indian,North Indian,Chinese,Biryani,Tandoor      1
# Chinese,Asian,Vietnamese,Pan-Asian,Seafood,Desserts           1
# Chaat,Snacks,Chinese                                          1
# Name: count, Length: 3733, dtype: int64

# %%
df.shape
# Out:
# (8675, 8)

# %%
#Univariate Analysis

# %%
#  categorical and numerical col
cat_col = df.select_dtypes(include=['object'])
cat_col
# Out:
#                         Area       City                Restaurant  \
# 0                Koramangala  Bangalore               Tandoor Hut
# 1                Koramangala  Bangalore             Tunday Kababi
# 2                  Jogupalya  Bangalore                   Kim Lee
# 3                Indiranagar  Bangalore         New Punjabi Hotel
# 4                Indiranagar  Bangalore                       Nh8
# ...                      ...        ...                       ...
# 8675  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677                  Rohini      Delhi      Chinese Kitchen King
# 8678                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679             Navrangpura  Ahmedabad              Sassy Street
#
#                                               Food type
# 0             Biryani,Chinese,North Indian,South Indian
# 1                                      Mughlai,Lucknowi
# ...

# %%
num_col = df.select_dtypes(include=['int64', 'float64'])
num_col
# Out:
#       Price  Avg ratings  Total ratings  Delivery time
# 0     300.0          4.4            100             59
# 1     300.0          4.1            100             56
# 2     650.0          4.4            100             50
# 3     250.0          3.9            500             57
# 4     350.0          4.0             50             63
# ...     ...          ...            ...            ...
# 8675  500.0          2.9             80             40
# 8676  200.0          2.9             80             28
# 8677  150.0          2.9             80             58
# 8678  150.0          2.9             80             28
# 8679  250.0          2.9             80             44
#
# [8675 rows x 4 columns]

# %%
num_col = ['Price', 'Avg ratings', 'Total ratings', 'Delivery time']
num_col
# Out:
# ['Price', 'Avg ratings', 'Total ratings', 'Delivery time']

# %%
# Visualization(NUMERICAL COLUMN)
for col in num_col:
    plt.figure(figsize=(12, 6))
    plt.hist(df[col], bins=30, edgecolor='k',alpha=0.6)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
#INSIGHTS FROM UNIVARIATE EDA(NUMERICAL COLUMNS)
#1-Price
#Most prices fall between ₹100 and ₹500.
#the max price is ₹2,500.

# %%
#2-Avg Ratings
#Ratings are centered around 3.0–4.8.
#The min rating is 2.0, and the maximum is 5.0.

# %%
#3-Total Ratings

#Most restaurants have ratings less than 200.

# %%
#4-Delivery Time

#Delivery times are between 30–80 minutes.

# %%
#Visualisation(CATEGORICAL COLUMN)

# %%
cat_col = ['Area', 'City', 'Restaurant', 'Food type']
cat_col
# Out:
# ['Area', 'City', 'Restaurant', 'Food type']

# %%
for col in cat_col:
    plt.figure(figsize=(12, 6))
    df[col].value_counts().head(10).plot(kind='bar', color='lightgreen', edgecolor='k')
    plt.title(f"Top Most Categories in {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.show()

# %%
#INSIGHTS FROM UNIVARIATE EDA(CATEGORICAL COLUMNS)

# %%
#Area:

#Rohini, Chembur, Kothrud are the top areas for food delivery.

#City:
#Most orders come from Kolkata, Mumbai, Chennai.


#Restaurant:
#La Pino'z Pizza, Nic Natural Ice Creams , Baskin Robbins are top restaurants .


#Food Type:
#Indian, Chinese , North Indian are top choices for orders.
#For mixed combinations Indian,Chinese are on top.

# %%
#BIVARIATE ANALYSIS

#Scatter plot 
plt.figure(figsize=(10, 5))
plt.scatter(df['Price'], df['Avg ratings'], edgecolor='g')
plt.title("Price vs. Avg Ratings")
plt.xlabel("Price")
plt.ylabel("Avg Ratings")
plt.grid(True)
plt.show()

# %%
#Insights>> with increase in prices ratings spread across the plot,
#increase or decrease in price does not produce higher ratings.

# %%
# Food Type vs. Avg Ratings
t_food = df['Food type'].value_counts().head(10).index
t_food_rows = df[df['Food type'].isin(t_food)]


t_food_rows.boxplot(column='Avg ratings', by='Food type', figsize=(12, 6), grid=False)
plt.title("Food Type vs. Avg Ratings")
plt.xlabel("Food Type")
plt.ylabel("Avg Ratings")
plt.xticks(rotation=45)
plt.suptitle("") 
plt.show()

# %%
#insights>>South Indian Food has the highest median ratings
#followed by the combination of North Indian ,Chinese and Desserts

# %%
t_area =df.groupby('Area')['Avg ratings'].mean().sort_values(ascending=False).head(10)


plt.figure(figsize=(10, 6))
t_area.plot(kind='bar', color='skyblue', edgecolor='k')
plt.title("Top 10 Areas with Highest Average Ratings")
plt.xlabel("Area")
plt.ylabel("Avg Ratings")
plt.xticks(rotation=45)
plt.show()

# %%
#Insights>>Girish Park has the highest average ratings

# %%
t_rest = df.groupby('Restaurant')['Total ratings'].sum().sort_values(ascending=False).head(10)

# Plot for Top 10 Restaurants by Total Ratings
plt.figure(figsize=(10, 6))
t_rest.plot(kind='bar', color='lightgreen', edgecolor='k')
plt.title("Top 10 Restaurants with Highest Total Ratings")
plt.xlabel("Restaurant")
plt.ylabel("Total Ratings")
plt.xticks(rotation=45)
plt.show()

# %%
#Insights>>SHAH Ghouse Cafe and Restaurant has the highest total ratings

# %%
#key insights>>
#Most prices fall between ₹100 and ₹500.

##Restaurant:
#La Pino'z Pizza, Nic Natural Ice Creams , Baskin Robbins are top restaurants .

#Indian, Chinese , North Indian are top choices for orders.
#For mixed combinations Indian,Chinese are on top.

#South Indian Food in Food type has the highest median ratings.

#Girish Park In Area has the highest average ratings.

#SHAH Ghouse Cafe and Restaurant in Retaurants has the highest total ratings.
